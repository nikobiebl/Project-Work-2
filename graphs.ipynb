# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Results Classifier

# %%
data = {
    'Classifier': ['MLP', 'LSVM', 'RF', 'LR', 'PSVM', 'MNB', 'KNN', 'GBM'],
    'Accuracy': [0.996, 0.995, 0.991, 0.989, 0.983, 0.979, 0.979, 0.943],
    'F1-Score': [0.996, 0.995, 0.991, 0.989, 0.983, 0.979, 0.979, 0.943],
    'Precision': [0.996, 0.995, 0.995, 0.986, 0.997, 0.994, 0.982, 0.928],
    'Recall': [0.996, 0.996, 0.987, 0.992, 0.969, 0.965, 0.976, 0.960],
    'Processing Time': ['11m 6s', '19m 7s', '1m 46.5s', '1.2s', '130m 49.7s', '0.2s', '33.2s', '2m 48.2s']
}

df = pd.DataFrame(data)
print(df)

ax = df.set_index('Classifier').plot(kind='bar', figsize=(12, 8))

plt.title('Performance Comparison of Classifiers')
plt.xlabel('Classifier')
plt.ylabel('Score')
plt.ylim(0.92, 1.0)

plt.legend(title='Metrics')
plt.xticks(rotation=0)

ax.xaxis.grid(False)
ax.yaxis.set_major_locator(plt.MultipleLocator(0.005))

plt.show()
# Out:
#   Classifier  Accuracy  F1-Score  Precision  Recall Processing Time
# 0        MLP     0.996     0.996      0.996   0.996          11m 6s
# 1       LSVM     0.995     0.995      0.995   0.996          19m 7s
# 2         RF     0.991     0.991      0.995   0.987        1m 46.5s
# 3         LR     0.989     0.989      0.986   0.992            1.2s
# 4       PSVM     0.983     0.983      0.997   0.969      130m 49.7s
# 5        MNB     0.979     0.979      0.994   0.965            0.2s
# 6        KNN     0.979     0.979      0.982   0.976           33.2s
# 7        GBM     0.943     0.943      0.928   0.960        2m 48.2s
